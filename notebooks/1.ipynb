# %%
import json

import pandas as pd

# %%
df = pd.read_excel('../data/1.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0 user_id  workday_id  task_id      task_load_number  \
# 0           0  TC1130           1       26  00100370009049374397
# 1           1   TC758           1       71  00100370009049680795
# 2           2  TC1002           1       28  00100370009049233342
# 3           3   TC758           1       70  00100370009049680788
# 4           4   TC758           1       69  00100370009049680771
#
#   work_day_start_time   work_day_end_time  work_day_time_diff  \
# 0 2024-08-01 08:02:56 2024-08-01 18:21:55               37139
# 1 2024-08-01 08:05:59 2024-08-01 18:36:36               37837
# 2 2024-08-01 08:00:31 2024-08-01 14:39:31               23940
# 3 2024-08-01 08:05:59 2024-08-01 18:36:36               37837
# 4 2024-08-01 08:05:59 2024-08-01 18:36:36               37837
#
#    unique_label_index                                 activity_code_path  ...  \
# 0                   2  ['List Pick', 'List Pick', 'List Pick', 'List ...  ...
# 1                   3                                      ['List Pick']  ...
# 2                   4                                      ['List Pick']  ...
# 3                   5                                      ['List Pick']  ...
# 4                   6  ['List Pick', 'List Pick', 'List Pick', 'List ...  ...
#
#                                         to_area_path  \
# 0  ['RDT Devices', 'RDT Devices', 'RDT Devices', ...
# 1                                    ['RDT Devices']
# 2                                    ['RDT Devices']
# 3                                    ['RDT Devices']
# 4  ['RDT Devices', 'RDT Devices', 'RDT Devices', ...
#
#                                     to_location_path  \
# 0  ['77D25C', '77D25C', '77D25C', '77D25C', '77D2...
# 1                                         ['77D1F4']
# 2                                         ['779724']
# 3                                         ['77D1F4']
# 4  ['77D1F4', '77D1F4', '77D1F4', '77D1F4', '77D1...
#
#                                transaction_date_path pick_time_diff  \
# 0  [Timestamp('2024-08-01 08:02:56'), Timestamp('...            977
# 1                 [Timestamp('2024-08-01 08:05:59')]              0
# 2                 [Timestamp('2024-08-01 08:08:02')]              0
# 3                 [Timestamp('2024-08-01 08:08:22')]              0
# 4  [Timestamp('2024-08-01 08:11:25'), Timestamp('...            441
#
#       pick_start_time       pick_end_time  \
# 0 2024-08-01 08:02:56 2024-08-01 08:19:13
# 1 2024-08-01 08:05:59 2024-08-01 08:05:59
# 2 2024-08-01 08:08:02 2024-08-01 08:08:02
# 3 2024-08-01 08:08:22 2024-08-01 08:08:22
# 4 2024-08-01 08:11:25 2024-08-01 08:18:46
#
#                                              sku_set  \
# 0  ['80754560', '80760464', '80754564', '80735217...
# 1                                       ['80741541']
# 2                                       ['80767193']
# 3                                       ['80804131']
# 4  ['80778727', '80707105', '80781278', '80781266...
#
#                                  sku_qty_in_cs_pairs pick_times  sku_nums
# 0  {'80735217': 9.0, '80736222': 24.0, '80752084'...          7         7
# 1                                 {'80741541': 21.0}          1         1
# 2                                 {'80767193': 32.0}          1         1
# 3                                  {'80804131': 6.0}          1         1
# 4  {'80689255': 33.0, '80707105': 18.0, '80718540...          8         8
#
# [5 rows x 26 columns]

# %%
df.set_index("unique_label_index", inplace=True)
df.head()
# Out:
#                     Unnamed: 0 user_id  workday_id  task_id  \
# unique_label_index
# 2                            0  TC1130           1       26
# 3                            1   TC758           1       71
# 4                            2  TC1002           1       28
# 5                            3   TC758           1       70
# 6                            4   TC758           1       69
#
#                         task_load_number work_day_start_time  \
# unique_label_index
# 2                   00100370009049374397 2024-08-01 08:02:56
# 3                   00100370009049680795 2024-08-01 08:05:59
# 4                   00100370009049233342 2024-08-01 08:00:31
# 5                   00100370009049680788 2024-08-01 08:05:59
# 6                   00100370009049680771 2024-08-01 08:05:59
#
#                      work_day_end_time  work_day_time_diff  \
# unique_label_index
# 2                  2024-08-01 18:21:55               37139
# 3                  2024-08-01 18:36:36               37837
# 4                  2024-08-01 14:39:31               23940
# 5                  2024-08-01 18:36:36               37837
# 6                  2024-08-01 18:36:36               37837
#
#                                                    activity_code_path  \
# unique_label_index
# 2                   ['List Pick', 'List Pick', 'List Pick', 'List ...
# 3                                                       ['List Pick']
# 4                                                       ['List Pick']
# 5                                                       ['List Pick']
# 6                   ['List Pick', 'List Pick', 'List Pick', 'List ...
#
#                                                   operation_code_path  ...  \
# unique_label_index                                                     ...
# 2                   ['List Pick', 'List Pick', 'List Pick', 'List ...  ...
# 3                                                       ['List Pick']  ...
# 4                                                       ['List Pick']  ...
# 5                                                       ['List Pick']  ...
# 6                   ['List Pick', 'List Pick', 'List Pick', 'List ...  ...
#
#                                                          to_area_path  \
# unique_label_index
# 2                   ['RDT Devices', 'RDT Devices', 'RDT Devices', ...
# 3                                                     ['RDT Devices']
# 4                                                     ['RDT Devices']
# 5                                                     ['RDT Devices']
# 6                   ['RDT Devices', 'RDT Devices', 'RDT Devices', ...
#
#                                                      to_location_path  \
# unique_label_index
# 2                   ['77D25C', '77D25C', '77D25C', '77D25C', '77D2...
# 3                                                          ['77D1F4']
# 4                                                          ['779724']
# 5                                                          ['77D1F4']
# 6                   ['77D1F4', '77D1F4', '77D1F4', '77D1F4', '77D1...
#
#                                                 transaction_date_path  \
# unique_label_index
# 2                   [Timestamp('2024-08-01 08:02:56'), Timestamp('...
# 3                                  [Timestamp('2024-08-01 08:05:59')]
# 4                                  [Timestamp('2024-08-01 08:08:02')]
# 5                                  [Timestamp('2024-08-01 08:08:22')]
# 6                   [Timestamp('2024-08-01 08:11:25'), Timestamp('...
#
#                    pick_time_diff     pick_start_time       pick_end_time  \
# unique_label_index
# 2                             977 2024-08-01 08:02:56 2024-08-01 08:19:13
# 3                               0 2024-08-01 08:05:59 2024-08-01 08:05:59
# 4                               0 2024-08-01 08:08:02 2024-08-01 08:08:02
# 5                               0 2024-08-01 08:08:22 2024-08-01 08:08:22
# 6                             441 2024-08-01 08:11:25 2024-08-01 08:18:46
#
#                                                               sku_set  \
# unique_label_index
# 2                   ['80754560', '80760464', '80754564', '80735217...
# 3                                                        ['80741541']
# 4                                                        ['80767193']
# 5                                                        ['80804131']
# 6                   ['80778727', '80707105', '80781278', '80781266...
#
#                                                   sku_qty_in_cs_pairs  \
# unique_label_index
# 2                   {'80735217': 9.0, '80736222': 24.0, '80752084'...
# 3                                                  {'80741541': 21.0}
# 4                                                  {'80767193': 32.0}
# 5                                                   {'80804131': 6.0}
# 6                   {'80689255': 33.0, '80707105': 18.0, '80718540...
#
#                     pick_times sku_nums
# unique_label_index
# 2                            7        7
# 3                            1        1
# 4                            1        1
# 5                            1        1
# 6                            8        8
#
# [5 rows x 25 columns]

# %%
df.sku_qty_in_cs_pairs
# Out:
# unique_label_index
# 2        {'80735217': 9.0, '80736222': 24.0, '80752084'...
# 3                                       {'80741541': 21.0}
# 4                                       {'80767193': 32.0}
# 5                                        {'80804131': 6.0}
# 6        {'80689255': 33.0, '80707105': 18.0, '80718540...
#                                ...
# 27568                                   {'80741454': 80.0}
# 27569                                    {'80741454': 5.0}
# 27570                                   {'80741454': 15.0}
# 27571                                    {'80741454': 1.0}
# 27572                                   {'80741454': 36.0}
# Name: sku_qty_in_cs_pairs, Length: 27546, dtype: object

# %%
def expand_dict_to_frame(df):
    data = eval(df.iloc[0]['sku_qty_in_cs_pairs'])
    new_df = pd.DataFrame(data.items(), columns=['sku_id', 'quantity'])
    return new_df
df2 = df.groupby(df.index).apply(expand_dict_to_frame)
df2.reset_index(level=0, inplace=True)
df2.rename(columns={'unique_label_index': 'order_id'}, inplace=True)
df2
# Out:
#     order_id    sku_id  quantity
# 0          2  80735217       9.0
# 1          2  80736222      24.0
# 2          2  80752084       6.0
# 3          2  80754560      23.0
# 4          2  80754564       2.0
# ..       ...       ...       ...
# 0      27568  80741454      80.0
# 0      27569  80741454       5.0
# 0      27570  80741454      15.0
# 0      27571  80741454       1.0
# 0      27572  80741454      36.0
#
# [112893 rows x 3 columns]
